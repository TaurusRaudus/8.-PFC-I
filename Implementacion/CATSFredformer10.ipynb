# %%
### CATS
### 3 epocas aproximadaemtne 10 segs
### 10 epocas aproximadamente 30 segs

import torch

import os, shutil
if os.path.exists('/content/CATS-main'):
    shutil.rmtree('/content/CATS-main')
# !unzip -q /content/CATS-main.zip -d /content/
# %cd /content/CATS-main


# !pip install -q matplotlib pandas scikit-learn

# !grep -rl "np.Inf" --include="*.py" . | xargs sed -i 's/np\.Inf/np.inf/g' 2>/dev/null
# !grep -rl "np.NaN" --include="*.py" . | xargs sed -i 's/np\.NaN/np.nan/g' 2>/dev/null

# !mkdir -p ./dataset/ETT-small
# !wget -q https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv -O ./dataset/ETT-small/ETTh1.csv
# !wget -q https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh2.csv -O ./dataset/ETT-small/ETTh2.csv
# !wget -q https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm1.csv -O ./dataset/ETT-small/ETTm1.csv
# !wget -q https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm2.csv -O ./dataset/ETT-small/ETTm2.csv

print()
print("Test original")

# !python -u run.py \
  --is_training 1 \
  --root_path ./dataset/ETT-small/ \
  --data_path ETTh1.csv \
  --model_id ETTh1_96_96_smoke \
  --model CATS \
  --data ETTh1 \
  --features M \
  --seq_len 96 \
  --pred_len 96 \
  --d_layers 3 \
  --dec_in 7 \
  --des 'test' \
  --itr 1 \
  --d_model 256 \
  --d_ff 512 \
  --n_heads 32 \
  --QAM_end 0.2 \
  --batch_size 256 \
  --patch_len 48 \
  --stride 48 \
  --train_epochs 10 \
  --num_workers 2
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# /content/CATS-main
#
# Test original
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh1_96_96_smoke', model='CATS', data='ETTh1', root_path='./dataset/ETT-small/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', inverse=False, ratios='0.7,0.1,0.2', seq_len=96, label_len=48, pred_len=96, dec_in=7, d_model=256, n_heads=32, e_layers=0, d_layers=3, d_ff=512, dropout=0.2, embed='timeF', use_norm=1, num_workers=2, itr=1, train_epochs=10, batch_size=256, patience=10, learning_rate=0.001, des='test', loss='MSE', lradj='type2', use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, QAM_start=0.1, QAM_end=0.2, patch_len=48, stride=48, pct_start=0.3, padding_patch='end', query_independence=False, store_attn=False)
# check
# Use GPU: cuda:0
# >>>>>>>start training : ETTh1_96_96_smoke_CATS_ETTh1_sl96_pl96_dm256_nh32_dl3_df512_qiFalse_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# Epoch: 1 cost time: 1.5254290103912354
# Epoch: 1, Steps: 33 | Train Loss: 0.5826132 Vali Loss: 0.9428211 Test Loss: 0.5503167
# Validation loss decreased (inf --> 0.942821).  Saving model ...
# Epoch: 2 cost time: 1.2013261318206787
# Epoch: 2, Steps: 33 | Train Loss: 0.4650821 Vali Loss: 0.7993544 Test Loss: 0.4498774
# Validation loss decreased (0.942821 --> 0.799354).  Saving model ...
# Updating learning rate to 0.0005
# Epoch: 3 cost time: 1.1849064826965332
# Epoch: 3, Steps: 33 | Train Loss: 0.4066622 Vali Loss: 0.7256452 Test Loss: 0.3940710
# Validation loss decreased (0.799354 --> 0.725645).  Saving model ...
# Epoch: 4 cost time: 1.1827354431152344
# Epoch: 4, Steps: 33 | Train Loss: 0.3743110 Vali Loss: 0.7032367 Test Loss: 0.3796836
# Validation loss decreased (0.725645 --> 0.703237).  Saving model ...
# Updating learning rate to 0.00025
# Epoch: 5 cost time: 1.347261667251587
# Epoch: 5, Steps: 33 | Train Loss: 0.3669739 Vali Loss: 0.6927254 Test Loss: 0.3772714
# Validation loss decreased (0.703237 --> 0.692725).  Saving model ...
# Epoch: 6 cost time: 1.2548654079437256
# Epoch: 6, Steps: 33 | Train Loss: 0.3619312 Vali Loss: 0.6922435 Test Loss: 0.3731321
# Validation loss decreased (0.692725 --> 0.692243).  Saving model ...
# Updating learning rate to 0.000125
# Epoch: 7 cost time: 1.1974332332611084
# Epoch: 7, Steps: 33 | Train Loss: 0.3582659 Vali Loss: 0.6878693 Test Loss: 0.3716963
# Validation loss decreased (0.692243 --> 0.687869).  Saving model ...
# Epoch: 8 cost time: 1.1926374435424805
# Epoch: 8, Steps: 33 | Train Loss: 0.3545696 Vali Loss: 0.6948729 Test Loss: 0.3704589
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 6.25e-05
# Epoch: 9 cost time: 1.2088654041290283
# Epoch: 9, Steps: 33 | Train Loss: 0.3553135 Vali Loss: 0.7002820 Test Loss: 0.3693519
# EarlyStopping counter: 2 out of 10
# Epoch: 10 cost time: 1.211198091506958
# Epoch: 10, Steps: 33 | Train Loss: 0.3515674 Vali Loss: 0.6928949 Test Loss: 0.3683930
# EarlyStopping counter: 3 out of 10
# Updating learning rate to 3.125e-05
# >>>>>>>testing : ETTh1_96_96_smoke_CATS_ETTh1_sl96_pl96_dm256_nh32_dl3_df512_qiFalse_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# mse:0.371696412563324, mae:0.39527738094329834, rmse:0.6096690893173218

# %%
### Fredformer
### 3 epocas 30 segs aprox
### 10 epocas 1 min aprox

import torch, os, shutil, time

if os.path.exists('/content/Fredformer-main'):
    shutil.rmtree('/content/Fredformer-main')
# !unzip -q /content/Fredformer-main.zip -d /content/
# %cd /content/Fredformer-main

# !pip install -q einops reformer-pytorch sktime torchinfo thop

# !grep -rl "np\.Inf" --include="*.py" . | xargs -r sed -i 's/np\.Inf/np.inf/g'
# !grep -rl "np\.NaN" --include="*.py" . | xargs -r sed -i 's/np\.NaN/np.nan/g'


# !mkdir -p ./dataset
# !wget -q https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv -O ./dataset/ETTh1.csv
# !wget -q https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh2.csv -O ./dataset/ETTh2.csv
# !wget -q https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm1.csv -O ./dataset/ETTm1.csv
# !wget -q https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTm2.csv -O ./dataset/ETTm2.csv
for pred_len in [96]:
    print()
    print("Test")

    # !python -u run_longExp.py \
      --random_seed 2021 \
      --is_training 1 \
      --root_path ./dataset/ \
      --data_path ETTh1.csv \
      --model_id ETTh1_96_{pred_len} \
      --model Fredformer \
      --data ETTh1 \
      --features M \
      --seq_len 96 \
      --pred_len {pred_len} \
      --enc_in 7 \
      --d_model 24 \
      --d_ff 128 \
      --dropout 0.3 \
      --fc_dropout 0.3 \
      --patch_len 4 \
      --stride 4 \
      --des 'Test Fredformer' \
      --train_epochs 10 \
      --patience 10 \
      --itr 1 \
      --batch_size 128 \
      --learning_rate 0.0001 \
      --cf_dim 128 \
      --cf_depth 2 \
      --cf_heads 8 \
      --cf_mlp 96 \
      --cf_head_dim 32 \
      --use_nys 0 \
      --individual 0 \
      --num_workers 2
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# /content/Fredformer-main
#
# Test
# Args in experiment:
# Namespace(cf_dim=128, cf_drop=0.2, cf_depth=2, cf_heads=8, cf_mlp=96, cf_head_dim=32, cf_weight_decay=0, cf_p=1, use_nys=0, mlp_drop=0.3, ablation=0, random_seed=2021, is_training=1, model_id='ETTh1_96_96', model='Fredformer', data='ETTh1', root_path='./dataset/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=96, label_len=48, pred_len=96, fc_dropout=0.3, head_dropout=0.0, patch_len=4, stride=4, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=24, mlp_hidden=64, n_heads=8, e_layers=2, d_layers=1, d_ff=128, moving_avg=25, factor=1, distil=True, dropout=0.3, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=128, patience=10, learning_rate=0.0001, des='Test Fredformer', loss='mse', lradj='type3', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2', test_flop=False)
# Use GPU: cuda:0
# FLOPS: 14.347G, MACs: 8.536M
# >>>>>>>start training : ETTh1_96_96_Fredformer_ETTh1.csv_cf_dim128_cf_depth2_cf_heads8_cf_mlp96_cf_head_dim32_10>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# Epoch: 1 cost time: 3.7939364910125732
# Epoch: 1, Steps: 66 | Train Loss: 0.5395972 Vali Loss: 1.1127790 Test Loss: 0.6743146
# Validation loss decreased (inf --> 1.112779).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.423753499984741
# Epoch: 2, Steps: 66 | Train Loss: 0.4118179 Vali Loss: 0.7091401 Test Loss: 0.3926587
# Validation loss decreased (1.112779 --> 0.709140).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 3 cost time: 3.4761176109313965
# Epoch: 3, Steps: 66 | Train Loss: 0.3604075 Vali Loss: 0.6956180 Test Loss: 0.3790284
# Validation loss decreased (0.709140 --> 0.695618).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 4 cost time: 3.421391248703003
# Epoch: 4, Steps: 66 | Train Loss: 0.3522624 Vali Loss: 0.6949331 Test Loss: 0.3776174
# Validation loss decreased (0.695618 --> 0.694933).  Saving model ...
# Updating learning rate to 9e-05
# Epoch: 5 cost time: 3.48421573638916
# Epoch: 5, Steps: 66 | Train Loss: 0.3472951 Vali Loss: 0.6898621 Test Loss: 0.3760050
# Validation loss decreased (0.694933 --> 0.689862).  Saving model ...
# Updating learning rate to 8.1e-05
# Epoch: 6 cost time: 3.433793544769287
# Epoch: 6, Steps: 66 | Train Loss: 0.3429758 Vali Loss: 0.6964505 Test Loss: 0.3755624
# EarlyStopping counter: 1 out of 10
# Updating learning rate to 7.290000000000001e-05
# Epoch: 7 cost time: 3.4464149475097656
# Epoch: 7, Steps: 66 | Train Loss: 0.3387287 Vali Loss: 0.6924535 Test Loss: 0.3731205
# EarlyStopping counter: 2 out of 10
# Updating learning rate to 6.561e-05
# Epoch: 8 cost time: 3.5232927799224854
# Epoch: 8, Steps: 66 | Train Loss: 0.3350049 Vali Loss: 0.6959208 Test Loss: 0.3711463
# EarlyStopping counter: 3 out of 10
# Updating learning rate to 5.904900000000001e-05
# Epoch: 9 cost time: 3.489419937133789
# Epoch: 9, Steps: 66 | Train Loss: 0.3316401 Vali Loss: 0.6924580 Test Loss: 0.3707258
# EarlyStopping counter: 4 out of 10
# Updating learning rate to 5.3144100000000005e-05
# Epoch: 10 cost time: 3.563922166824341
# Epoch: 10, Steps: 66 | Train Loss: 0.3284640 Vali Loss: 0.7092263 Test Loss: 0.3720876
# EarlyStopping counter: 5 out of 10
# Updating learning rate to 4.782969000000001e-05
# >>>>>>>testing : ETTh1_96_96_Fredformer_ETTh1.csv_cf_dim128_cf_depth2_cf_heads8_cf_mlp96_cf_head_dim32_10<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# mse:0.3760049641132355, mae:0.39402705430984497, rse:0.5814498066902161

# %% [markdown]
# Para 10 epocas (GPU 4)
#
# CATS 10 segs
#
# test 2785
# mse:0.371696412563324, mae:0.39527738094329834, rmse:0.6096690893173218
#
# Fredformer 59 segs
#
# test 2785
# mse:0.3760049641132355, mae:0.39402705430984497, rse:0.5814498066902161
#
#
#
#
#
# CATS: Mejor MSE, Entrenamiento veloz
#
# Fredformer: Mejor MAE,
